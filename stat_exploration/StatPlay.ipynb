# %% [markdown]
# ### PURPOSE: To read review our data munging csv, store in a DataFrame, and perform statistics

# %%
#import necessary packages
import pandas as pd
import scipy.stats as stats

# %%
#build data frame
restaurants_raw = pd.read_csv("../called/la_restaurants_yelped17.csv")
restaurants_raw.head()
# Out:
#    Unnamed: 0 serial_number           activity_date          facility_name  \
# 0           0     DAKG00TSQ  07/20/2015 12:00:00 AM               HONEYMEE
# 1           1     DAEBCA0RE  07/20/2015 12:00:00 AM  KURA JAPANESE CUISINE
# 2           2     DAEBCA0RE  07/20/2015 12:00:00 AM  KURA JAPANESE CUISINE
# 3           3     DAYJJHNWJ  11/18/2015 12:00:00 AM  KURA JAPANESE CUISINE
# 4           4     DAYJJHNWJ  11/18/2015 12:00:00 AM  KURA JAPANESE CUISINE
#
#    score grade  service_code service_description employee_id  \
# 0     93     A             1  ROUTINE INSPECTION   EE0000699
# 1     92     A             1  ROUTINE INSPECTION   EE0000838
# 2     92     A             1  ROUTINE INSPECTION   EE0000838
# 3     92     A             1  ROUTINE INSPECTION   EE0000838
# 4     92     A             1  ROUTINE INSPECTION   EE0000838
#
#          facility_address           ...           program_status  record_id  \
# ...

# %%
restaurants_scrub = restaurants_raw.drop('Unnamed: 0', axis=1)
restaurants_scrub.head()
# Out:
#   serial_number           activity_date          facility_name  score grade  \
# 0     DAKG00TSQ  07/20/2015 12:00:00 AM               HONEYMEE     93     A
# 1     DAEBCA0RE  07/20/2015 12:00:00 AM  KURA JAPANESE CUISINE     92     A
# 2     DAEBCA0RE  07/20/2015 12:00:00 AM  KURA JAPANESE CUISINE     92     A
# 3     DAYJJHNWJ  11/18/2015 12:00:00 AM  KURA JAPANESE CUISINE     92     A
# 4     DAYJJHNWJ  11/18/2015 12:00:00 AM  KURA JAPANESE CUISINE     92     A
#
#    service_code service_description employee_id        facility_address  \
# 0             1  ROUTINE INSPECTION   EE0000699  3377 WILSHIRE BLVD 116
# 1             1  ROUTINE INSPECTION   EE0000838      8162 W SUNSET BLVD
# 2             1  ROUTINE INSPECTION   EE0000838      8162 W SUNSET BLVD
# 3             1  ROUTINE INSPECTION   EE0000838      8162 W SUNSET BLVD
# 4             1  ROUTINE INSPECTION   EE0000838      8162 W SUNSET BLVD
#
#   facility_city           ...           program_status  record_id  \
# ...

# %%
restaurants_scrub.duplicated()
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4        True
# 5       False
# 6        True
# 7       False
# 8        True
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19       True
# 20      False
# 21       True
# 22      False
# 23       True
# 24      False
# 25       True
# 26      False
# 27      False
# 28      False
# 29       True
#         ...
# 2680    False
# 2681    False
# 2682    False
# 2683    False
# 2684    False
# 2685    False
# 2686    False
# 2687    False
# 2688    False
# 2689    False
# 2690    False
# 2691    False
# 2692    False
# 2693    False
# 2694    False
# 2695    False
# 2696    False
# 2697    False
# 2698    False
# 2699    False
# 2700    False
# 2701    False
# 2702    False
# 2703    False
# 2704    False
# 2705    False
# 2706    False
# 2707    False
# 2708    False
# 2709    False
# ...

# %%
restaurants_scrub = restaurants_scrub.drop_duplicates()

# %%
restaurants_scrub.head()
# Out:
#   serial_number           activity_date          facility_name  score grade  \
# 0     DAKG00TSQ  07/20/2015 12:00:00 AM               HONEYMEE     93     A
# 1     DAEBCA0RE  07/20/2015 12:00:00 AM  KURA JAPANESE CUISINE     92     A
# 3     DAYJJHNWJ  11/18/2015 12:00:00 AM  KURA JAPANESE CUISINE     92     A
# 5     DAT3YETFG  07/20/2015 12:00:00 AM          EL GALLO GIRO     90     A
# 7     DA03STEHU  12/01/2015 12:00:00 AM          EL GALLO GIRO     95     A
#
#    service_code service_description employee_id        facility_address  \
# 0             1  ROUTINE INSPECTION   EE0000699  3377 WILSHIRE BLVD 116
# 1             1  ROUTINE INSPECTION   EE0000838      8162 W SUNSET BLVD
# 3             1  ROUTINE INSPECTION   EE0000838      8162 W SUNSET BLVD
# 5             1  ROUTINE INSPECTION   EE0000707    701 E JEFFERSON BLVD
# 7             1  ROUTINE INSPECTION   EE0000707    701 E JEFFERSON BLVD
#
#   facility_city           ...           program_status  record_id  \
# ...

# %%
restaurants_scrub = restaurants_scrub.drop('serial_number', axis=1)
#restaurants_scrub.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-c8cd0e2fc09b> in <module>()
# ----> 1 restaurants_scrub = restaurants_scrub.drop('serial_number', axis=1)
#       2 restaurants_scrub.drop_duplicates()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# ...

# %%
restaurants_scrub.drop_duplicates()
# Out:
#                activity_date                   facility_name  score grade  \
# 0     07/20/2015 12:00:00 AM                        HONEYMEE     93     A
# 1     07/20/2015 12:00:00 AM           KURA JAPANESE CUISINE     92     A
# 3     11/18/2015 12:00:00 AM           KURA JAPANESE CUISINE     92     A
# 5     07/20/2015 12:00:00 AM                   EL GALLO GIRO     90     A
# 7     12/01/2015 12:00:00 AM                   EL GALLO GIRO     95     A
# 9     07/20/2015 12:00:00 AM          WINCHELL'S DONUT #9339     87     B
# 10    07/20/2015 12:00:00 AM                   CHARLIES TRIO     93     A
# 11    07/20/2015 12:00:00 AM                  TACOS BAJA INC     80     B
# 12    07/20/2015 12:00:00 AM                          BESTIA     92     A
# 13    07/20/2015 12:00:00 AM        CASA HONDURAS RESTAURANT     93     A
# 14    07/20/2015 12:00:00 AM                   EL POLLO LOCO     96     A
# 15    07/20/2015 12:00:00 AM              MCDONALD'S # 25642     90     A
# ...

# %%
restaurants_scrub.count()
# Out:
# activity_date          2224
# facility_name          2224
# score                  2224
# grade                  2224
# service_code           2224
# service_description    2224
# employee_id            2224
# facility_address       2224
# facility_city          2224
# facility_id            2224
# facility_state         2224
# facility_zip           2224
# owner_id               2224
# owner_name             2224
# pe_description         2224
# program_element_pe     2224
# program_name           2224
# program_status         2224
# record_id              2224
# food_type              2224
# in_business            2224
# latitude               2224
# longitude              2224
# price                  2224
# rating                 2224
# review_count           2224
# yelp_id                2224
# dtype: int64

# %%
restaurants_scrub = restaurants_scrub[['facility_name', 'score', 'grade', 'facility_id','price', 'rating', 'review_count', 'yelp_id']]

# %%
restaurants_scrub.drop_duplicates()
restaurants_scrub.count()
# Out:
# facility_name    2224
# score            2224
# grade            2224
# facility_id      2224
# price            2224
# rating           2224
# review_count     2224
# yelp_id          2224
# dtype: int64
