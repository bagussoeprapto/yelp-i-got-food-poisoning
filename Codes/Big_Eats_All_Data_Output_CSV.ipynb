# %%
#Magic
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %%
#Dependencies
import os
import pandas as pd
import numpy as np
import glob
from matplotlib import pyplot as plt

# %%
filepath = "called/**"
all_csv_files = glob.glob(os.path.join(filepath, "*.csv"), recursive = True)

grades_n_yelp_df = (pd.read_csv(f) for f in all_csv_files)
raw_restaurants_df = pd.concat(grades_n_yelp_df, ignore_index=True)


#all_restaurants_df=pd.concat(map(pd.read_csv, filepath))
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False

# %%
raw_restaurants_df.head()
# Out:
#    Unnamed: 0           activity_date employee_id  \
# 0           0  11/17/2015 12:00:00 AM   EE0000726
# 1           1  11/17/2015 12:00:00 AM   EE0000726
# 2           2  11/06/2015 12:00:00 AM   EE0000726
# 3           3  11/06/2015 12:00:00 AM   EE0000726
# 4           4  11/17/2015 12:00:00 AM   EE0000950
#
#                facility_address facility_city facility_id       facility_name  \
# 0             7669 BEVERLY BLVD   LOS ANGELES   FA0025994  NAKKARA ON BEVERLY
# 1             7669 BEVERLY BLVD   LOS ANGELES   FA0025994  NAKKARA ON BEVERLY
# 2             7669 BEVERLY BLVD   LOS ANGELES   FA0025994  NAKKARA ON BEVERLY
# 3             7669 BEVERLY BLVD   LOS ANGELES   FA0025994  NAKKARA ON BEVERLY
# 4  6600 E OLYMPIC BLVD STE #106   LOS ANGELES   FA0055785      YUM YUM DONUTS
#
#   facility_state facility_zip                   food_type  \
# 0             CA        90036    ['Thai', 'Asian Fusion']
# 1             CA        90036    ['Thai', 'Asian Fusion']
# 2             CA        90036    ['Thai', 'Asian Fusion']
# 3             CA        90036    ['Thai', 'Asian Fusion']
# 4             CA        90022  ['Donuts', 'Coffee & Tea']
#
#             ...                  program_name  program_status  rating  \
# 0           ...            NAKKARA ON BEVERLY          ACTIVE     3.5
# 1           ...            NAKKARA ON BEVERLY          ACTIVE     3.5
# 2           ...            NAKKARA ON BEVERLY          ACTIVE     3.5
# 3           ...            NAKKARA ON BEVERLY          ACTIVE     3.5
# 4           ...                YUM YUM DONUTS        INACTIVE     3.5
#
#    record_id  review_count score serial_number service_code  \
# 0  PR0030608           270    91     DAPDUDULO          401
# 1  PR0030608           270    91     DAPDUDULO          401
# 2  PR0030608           270    81     DA6GMZWE0            1
# 3  PR0030608           270    81     DA6GMZWE0            1
# 4  PR0047011            24    92     DATA6A0QP            1
#
#                 service_description                 yelp_id
# 0  OWNER INITIATED ROUTINE INSPECT.  m3xOrOOqdsvE9ygMyHSpZQ
# 1  OWNER INITIATED ROUTINE INSPECT.  m3xOrOOqdsvE9ygMyHSpZQ
# 2                ROUTINE INSPECTION  m3xOrOOqdsvE9ygMyHSpZQ
# 3                ROUTINE INSPECTION  m3xOrOOqdsvE9ygMyHSpZQ
# 4                ROUTINE INSPECTION  x0brWIP6TsqeT80ERX_mHQ
#
# [5 rows x 30 columns]

# %%
# Output BIG dataframe to CSV
raw_restaurants_df.to_csv("raw_all_restaurants.csv", header=True)
